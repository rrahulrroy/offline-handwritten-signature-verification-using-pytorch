# %% [markdown]
# <a href="https://colab.research.google.com/github/rrahulrroy/offline-handwritten-signature-verification-using-pytorch/blob/master/hand_sign_recgn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
ls
# Out:
# sample_data/

# %%
pwd
# Out:
# '/content'

# %%
mkdir hsr

# %%
ls
# Out:
# hsr/  sample_data/

# %%
cd hsr
# Out:
# /content/hsr

# %%
cd ..
# Out:
# /content

# %%
cd ..
# Out:
# /

# %%
cd root
# Out:
# /root

# %%
cd .kaggle
# Out:
# /root/.kaggle

# %%
from google.colab import files
upload = files.upload()
# Out:
#      <input type="file" id="files-b28b353c-e910-4a41-a784-c3761861eb49" name="files[]" multiple disabled />
#      <output id="result-b28b353c-e910-4a41-a784-c3761861eb49">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json

# %%
cd ..
# Out:
# /root

# %%
cd ..
# Out:
# /

# %%
cd content
# Out:
# /content

# %%
cd hsr
# Out:
# /content/hsr

# %%
ls

# %%
# !kaggle datasets download -d robinreni/signature-verification-dataset
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /root/.kaggle/kaggle.json'
# Downloading signature-verification-dataset.zip to /content/hsr
#  93% 278M/300M [00:01<00:00, 242MB/s]
# 100% 300M/300M [00:01<00:00, 225MB/s]

# %%
ls
# Out:
# signature-verification-dataset.zip

# %%
# !unzip signature-verification-dataset.zip

# %%
ls
# Out:
# signature-verification-dataset.zip  sign_data/

# %%
# Import all the necessary Library 
import torchvision
import torch.utils.data as utils
from torchvision import datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader,Dataset
from torch.autograd import Variable
import matplotlib.pyplot as plt
import torchvision.utils
import numpy as np
import time
import copy
from torch.optim import lr_scheduler
import os
from PIL import Image
import torch
from torch.autograd import Variable
import PIL.ImageOps    
import torch.nn as nn
from torch import optim
import torch.nn.functional as F
import pandas as pd

# %%
def imshow(img,text=None,should_save=False):
    npimg = img.numpy()
    plt.axis("off")
    if text:
        plt.text(75, 8, text, style='italic',fontweight='bold',
            bbox={'facecolor':'white', 'alpha':0.8, 'pad':10})
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()    

def show_plot(iteration,loss):
    plt.plot(iteration,loss)
    plt.show()

# %%
class Config():
    training_dir = "/content/hsr/sign_data/train"
    testing_dir = "/content/hsr/sign_data/test"
    train_batch_size = 32
    train_number_epochs = 20

# %%
training_dir="/content/hsr/sign_data/train"
training_csv="/content/hsr/sign_data/train_data.csv"
testing_csv="/content/hsr/sign_data/test_data.csv"
testing_dir="/content/hsr/sign_data/test"

# %%
class SiameseNetworkDataset():
    
    def __init__(self,training_csv=None,training_dir=None,transform=None):
        # used to prepare the labels and images path
        self.training_df=pd.read_csv(training_csv)
        self.training_df.columns =["image1","image2","label"]
        self.training_dir = training_dir    
        self.transform = transform

    def __getitem__(self,index):
        
        # getting the image path
        image1_path=os.path.join(self.training_dir,self.training_df.iat[index,0])
        image2_path=os.path.join(self.training_dir,self.training_df.iat[index,1])
        
        
        # Loading the image
        img0 = Image.open(image1_path)
        img1 = Image.open(image2_path)
        img0 = img0.convert("L")
        img1 = img1.convert("L")
        
        # Apply image transformations
        if self.transform is not None:
            img0 = self.transform(img0)
            img1 = self.transform(img1)
        
        return img0, img1 , torch.from_numpy(np.array([int(self.training_df.iat[index,2])],dtype=np.float32))
    
    def __len__(self):
        return len(self.training_df)

# %%
# Load the the dataset from raw image folders
siamese_dataset = SiameseNetworkDataset(training_csv,training_dir,
                                        transform=transforms.Compose([transforms.Resize((105,105)),
                                                                      transforms.ToTensor()
                                                                      ]))

# %%
# Viewing the sample of images and to check whether its loading properly
vis_dataloader = DataLoader(siamese_dataset,
                        shuffle=True,
                        batch_size=8)
dataiter = iter(vis_dataloader)


example_batch = next(dataiter)
concatenated = torch.cat((example_batch[0],example_batch[1]),0)
imshow(torchvision.utils.make_grid(concatenated))
print(example_batch[2].numpy())
# Out:
# [[0.]
#  [1.]
#  [0.]
#  [1.]
#  [0.]
#  [1.]
#  [0.]
#  [1.]]

# %%
class SiameseNetwork(nn.Module):
    def __init__(self):
        super(SiameseNetwork, self).__init__()
        
        # Setting up the Sequential of CNN Layers
        self.cnn1 = nn.Sequential(
            
            nn.Conv2d(1, 96, kernel_size=11,stride=1),
            nn.ReLU(inplace=True),
            nn.LocalResponseNorm(5,alpha=0.0001,beta=0.75,k=2),
            nn.MaxPool2d(3, stride=2),
            
            nn.Conv2d(96, 256, kernel_size=5,stride=1,padding=2),
            nn.ReLU(inplace=True),
            nn.LocalResponseNorm(5,alpha=0.0001,beta=0.75,k=2),
            nn.MaxPool2d(3, stride=2),
            nn.Dropout2d(p=0.3),

            nn.Conv2d(256,384 , kernel_size=3,stride=1,padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(384,256 , kernel_size=3,stride=1,padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(3, stride=2),
            nn.Dropout2d(p=0.3),

        )
        
        # Defining the fully connected layers
        self.fc1 = nn.Sequential(
            nn.Linear(30976, 1024),
            nn.ReLU(inplace=True),
            nn.Dropout2d(p=0.5),
            
            nn.Linear(1024, 128),
            nn.ReLU(inplace=True),
            
            nn.Linear(128,2))
        
  
  
    def forward_once(self, x):
        # Forward pass 
        output = self.cnn1(x)
        output = output.view(output.size()[0], -1)
        output = self.fc1(output)
        return output

    def forward(self, input1, input2):
        # forward pass of input 1
        output1 = self.forward_once(input1)
        # forward pass of input 2
        output2 = self.forward_once(input2)
        return output1, output2

# %%
class ContrastiveLoss(torch.nn.Module):
    """
    Contrastive loss function.
    Based on: http://yann.lecun.com/exdb/publis/pdf/hadsell-chopra-lecun-06.pdf
    """

    def __init__(self, margin=2.0):
        super(ContrastiveLoss, self).__init__()
        self.margin = margin

    def forward(self, output1, output2, label):
        euclidean_distance = F.pairwise_distance(output1, output2)
        loss_contrastive = torch.mean((1-label) * torch.pow(euclidean_distance, 2) +
                                      (label) * torch.pow(torch.clamp(self.margin - euclidean_distance, min=0.0), 2))


        return loss_contrastive

# %%
# Load the dataset as pytorch tensors using dataloader
train_dataloader = DataLoader(siamese_dataset,
                        shuffle=True,
                        num_workers=8,
                        batch_size=Config.train_batch_size)

# %%
# Check whether you have GPU loaded or not
if torch.cuda.is_available():
    print('Yes')
# Out:
# Yes

# %%
# Declare Siamese Network
net = SiameseNetwork().cuda()
#net = SiameseNetwork()
# Decalre Loss Function
criterion = ContrastiveLoss()
# Declare Optimizer
optimizer = optim.RMSprop(net.parameters(), lr=1e-4, alpha=0.99, eps=1e-8, weight_decay=0.0005, momentum=0.9)

# %%
def train():
    counter = []
    loss_history = [] 
    iteration_number= 0
    
    for epoch in range(0,Config.train_number_epochs):
        for i, data in enumerate(train_dataloader,0):
            img0, img1 , label = data
            img0, img1 , label = img0.cuda(), img1.cuda() , label.cuda()
            optimizer.zero_grad()
            output1,output2 = net(img0,img1)
            loss_contrastive = criterion(output1,output2,label)
            loss_contrastive.backward()
            optimizer.step()
            if i %50 == 0 :
                print("Epoch number {}\n Current loss {}\n".format(epoch,loss_contrastive.item()))
                iteration_number +=10
                counter.append(iteration_number)
                loss_history.append(loss_contrastive.item())
    return net

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# Train the model
model = train()
torch.save(model.state_dict(), "model.pt")
print("Model Saved Successfully")
# Out:
# Epoch number 0
#  Current loss 2.237574338912964
#
# Epoch number 0
#  Current loss 0.8034970760345459
#
# Epoch number 0
#  Current loss 1.2698519229888916
#
# Epoch number 0
#  Current loss 1.456235647201538
#
# Epoch number 0
#  Current loss 1.223221778869629
#
# Epoch number 0
#  Current loss 0.9573705792427063
#
# Epoch number 0
#  Current loss 1.322342872619629
#
# Epoch number 0
#  Current loss 1.6536921262741089
#
# Epoch number 0
#  Current loss 1.291137456893921
#
# Epoch number 0
#  Current loss 1.3012142181396484
#
# Epoch number 0
#  Current loss 1.3260473012924194
#
# Epoch number 0
#  Current loss 1.4616574048995972
#
# Epoch number 0
#  Current loss 1.1353492736816406
#
# Epoch number 0
#  Current loss 1.0693674087524414
#
# Epoch number 0
#  Current loss 1.33540678024292
#
# Epoch number 1
#  Current loss 1.143424391746521
#
# Epoch number 1
#  Current loss 1.199282169342041
#
# Epoch number 1
#  Current loss 1.2831231355667114
#
# Epoch number 1
#  Current loss 2.033888101577759
#
# Epoch number 1
#  Current loss 1.3843116760253906
#
# Epoch number 1
#  Current loss 1.2666802406311035
#
# Epoch number 1
#  Current loss 1.1439316272735596
#
# Epoch number 1
#  Current loss 1.1137840747833252
#
# Epoch number 1
#  Current loss 1.1242890357971191
#
# Epoch number 1
#  Current loss 1.5525578260421753
#
# Epoch number 1
#  Current loss 1.3842782974243164
#
# Epoch number 1
#  Current loss 1.1181175708770752
#
# Epoch number 1
#  Current loss 1.3508732318878174
#
# Epoch number 1
#  Current loss 1.244642734527588
#
# Epoch number 1
#  Current loss 1.1811566352844238
#
# Epoch number 2
#  Current loss 1.025387167930603
#
# Epoch number 2
#  Current loss 0.9754750728607178
#
# Epoch number 2
#  Current loss 0.9995815753936768
#
# Epoch number 2
#  Current loss 1.2961277961730957
#
# Epoch number 2
#  Current loss 1.2436647415161133
#
# Epoch number 2
#  Current loss 1.2386937141418457
#
# Epoch number 2
#  Current loss 1.3846888542175293
#
# Epoch number 2
#  Current loss 1.218029260635376
#
# Epoch number 2
#  Current loss 1.2573180198669434
#
# Epoch number 2
#  Current loss 1.045597791671753
#
# Epoch number 2
#  Current loss 0.9029834270477295
#
# Epoch number 2
#  Current loss 1.1938934326171875
#
# Epoch number 2
#  Current loss 1.1771843433380127
#
# Epoch number 2
#  Current loss 1.1846644878387451
#
# Epoch number 2
#  Current loss 1.1052440404891968
#
# Epoch number 3
#  Current loss 1.4747103452682495
#
# Epoch number 3
#  Current loss 1.1584126949310303
#
# Epoch number 3
#  Current loss 1.2310032844543457
#
# Epoch number 3
#  Current loss 1.3663763999938965
#
# Epoch number 3
#  Current loss 1.1846543550491333
#
# Epoch number 3
#  Current loss 1.126238226890564
#
# Epoch number 3
#  Current loss 1.217113733291626
#
# Epoch number 3
#  Current loss 1.2033400535583496
#
# Epoch number 3
#  Current loss 1.355176329612732
#
# Epoch number 3
#  Current loss 1.0667250156402588
#
# Epoch number 3
#  Current loss 1.3017313480377197
#
# Epoch number 3
#  Current loss 1.1765823364257812
#
# Epoch number 3
#  Current loss 1.1526572704315186
#
# Epoch number 3
#  Current loss 1.2144701480865479
#
# Epoch number 3
#  Current loss 1.1484133005142212
#
# Epoch number 4
#  Current loss 1.0840983390808105
#
# Epoch number 4
#  Current loss 1.2397027015686035
#
# Epoch number 4
#  Current loss 1.0798695087432861
#
# Epoch number 4
#  Current loss 1.0028787851333618
#
# Epoch number 4
#  Current loss 1.1001719236373901
#
# Epoch number 4
#  Current loss 1.1146776676177979
#
# Epoch number 4
#  Current loss 1.290433406829834
#
# Epoch number 4
#  Current loss 1.6190261840820312
#
# Epoch number 4
#  Current loss 1.3125557899475098
#
# Epoch number 4
#  Current loss 1.0106256008148193
#
# Epoch number 4
#  Current loss 1.1123099327087402
#
# Epoch number 4
#  Current loss 1.3064391613006592
#
# Epoch number 4
#  Current loss 1.2027201652526855
#
# Epoch number 4
#  Current loss 1.1786060333251953
#
# Epoch number 4
#  Current loss 1.3108047246932983
#
# Epoch number 5
#  Current loss 1.4263255596160889
#
# Epoch number 5
#  Current loss 1.146620750427246
#
# Epoch number 5
#  Current loss 1.1797444820404053
#
# Epoch number 5
#  Current loss 1.2430706024169922
#
# Epoch number 5
#  Current loss 1.1140940189361572
#
# Epoch number 5
#  Current loss 1.0280059576034546
#
# Epoch number 5
#  Current loss 1.257387399673462
#
# Epoch number 5
#  Current loss 1.3187612295150757
#
# Epoch number 5
#  Current loss 1.1173570156097412
#
# Epoch number 5
#  Current loss 1.1581004858016968
#
# Epoch number 5
#  Current loss 1.2207732200622559
#
# Epoch number 5
#  Current loss 1.0920429229736328
#
# Epoch number 5
#  Current loss 1.2430779933929443
#
# Epoch number 5
#  Current loss 1.3998253345489502
#
# Epoch number 5
#  Current loss 1.2655820846557617
#
# Epoch number 6
#  Current loss 3.1618518829345703
#
# Epoch number 6
#  Current loss 1.2842178344726562
#
# Epoch number 6
#  Current loss 1.1278408765792847
#
# Epoch number 6
#  Current loss 1.0220341682434082
#
# Epoch number 6
#  Current loss 1.2507319450378418
#
# Epoch number 6
#  Current loss 1.094231128692627
#
# Epoch number 6
#  Current loss 1.2173335552215576
#
# Epoch number 6
#  Current loss 1.2823054790496826
#
# Epoch number 6
#  Current loss 1.1570113897323608
#
# Epoch number 6
#  Current loss 1.2644164562225342
#
# Epoch number 6
#  Current loss 1.2960526943206787
#
# Epoch number 6
#  Current loss 1.1250823736190796
#
# Epoch number 6
#  Current loss 1.1857343912124634
#
# Epoch number 6
#  Current loss 1.4768074750900269
#
# Epoch number 6
#  Current loss 1.2488917112350464
#
# Epoch number 7
#  Current loss 1.238208532333374
#
# Epoch number 7
#  Current loss 1.442251443862915
#
# Epoch number 7
#  Current loss 1.2838175296783447
#
# Epoch number 7
#  Current loss 1.3400462865829468
#
# Epoch number 7
#  Current loss 1.1980905532836914
#
# Epoch number 7
#  Current loss 1.096772313117981
#
# Epoch number 7
#  Current loss 1.1846694946289062
#
# Epoch number 7
#  Current loss 2.130777597427368
#
# Epoch number 7
#  Current loss 1.1489299535751343
#
# Epoch number 7
#  Current loss 1.3117133378982544
#
# Epoch number 7
#  Current loss 1.3669676780700684
#
# Epoch number 7
#  Current loss 1.4343620538711548
#
# Epoch number 7
#  Current loss 1.1862783432006836
#
# Epoch number 7
#  Current loss 1.2992947101593018
#
# Epoch number 7
#  Current loss 1.2539780139923096
#
# Epoch number 8
#  Current loss 1.2132253646850586
#
# Epoch number 8
#  Current loss 1.4650551080703735
#
# Epoch number 8
#  Current loss 1.1696438789367676
#
# Epoch number 8
#  Current loss 1.2749472856521606
#
# Epoch number 8
#  Current loss 1.334486722946167
#
# Epoch number 8
#  Current loss 1.19182288646698
#
# Epoch number 8
#  Current loss 1.0865557193756104
#
# Epoch number 8
#  Current loss 1.1967979669570923
#
# Epoch number 8
#  Current loss 1.2562121152877808
#
# Epoch number 8
#  Current loss 1.1429325342178345
#
# Epoch number 8
#  Current loss 1.235830545425415
#
# Epoch number 8
#  Current loss 1.2374359369277954
#
# Epoch number 8
#  Current loss 1.2189977169036865
#
# Epoch number 8
#  Current loss 1.135153889656067
#
# Epoch number 8
#  Current loss 1.19810152053833
#
# Epoch number 9
#  Current loss 1.1924453973770142
#
# Epoch number 9
#  Current loss 1.6958866119384766
#
# Epoch number 9
#  Current loss 1.1155625581741333
#
# Epoch number 9
#  Current loss 1.0852582454681396
#
# Epoch number 9
#  Current loss 1.1377956867218018
#
# Epoch number 9
#  Current loss 1.2346630096435547
#
# Epoch number 9
#  Current loss 1.2514550685882568
#
# Epoch number 9
#  Current loss 1.1346194744110107
#
# Epoch number 9
#  Current loss 1.1150925159454346
#
# Epoch number 9
#  Current loss 1.1820120811462402
#
# Epoch number 9
#  Current loss 1.1952354907989502
#
# Epoch number 9
#  Current loss 1.0825233459472656
#
# Epoch number 9
#  Current loss 1.0510101318359375
#
# Epoch number 9
#  Current loss 1.1704466342926025
#
# Epoch number 9
#  Current loss 1.3358476161956787
#
# Epoch number 10
#  Current loss 1.2411741018295288
#
# Epoch number 10
#  Current loss 1.475655436515808
#
# Epoch number 10
#  Current loss 1.1773929595947266
#
# Epoch number 10
#  Current loss 1.148013949394226
#
# Epoch number 10
#  Current loss 1.2136101722717285
#
# Epoch number 10
#  Current loss 1.2557615041732788
#
# Epoch number 10
#  Current loss 1.341691493988037
#
# Epoch number 10
#  Current loss 1.3293981552124023
#
# Epoch number 10
#  Current loss 1.197453260421753
#
# Epoch number 10
#  Current loss 1.212277889251709
#
# Epoch number 10
#  Current loss 1.3063745498657227
#
# Epoch number 10
#  Current loss 1.152308464050293
#
# Epoch number 10
#  Current loss 1.2196474075317383
#
# Epoch number 10
#  Current loss 1.278747320175171
#
# Epoch number 10
#  Current loss 1.1142069101333618
#
# Epoch number 11
#  Current loss 1.4054917097091675
#
# Epoch number 11
#  Current loss 1.2383196353912354
#
# Epoch number 11
#  Current loss 1.0978693962097168
#
# Epoch number 11
#  Current loss 1.4164090156555176
#
# Epoch number 11
#  Current loss 1.1686429977416992
#
# Epoch number 11
#  Current loss 0.821702241897583
#
# Epoch number 11
#  Current loss 1.2871289253234863
#
# Epoch number 11
#  Current loss 1.186179280281067
#
# Epoch number 11
#  Current loss 1.308706283569336
#
# Epoch number 11
#  Current loss 1.0261343717575073
#
# Epoch number 11
#  Current loss 1.0475231409072876
#
# Epoch number 11
#  Current loss 1.1735517978668213
#
# Epoch number 11
#  Current loss 1.521458625793457
#
# Epoch number 11
#  Current loss 1.2761831283569336
#
# Epoch number 11
#  Current loss 1.236840844154358
#
# Epoch number 12
#  Current loss 1.1593706607818604
#
# Epoch number 12
#  Current loss 1.1732072830200195
#
# Epoch number 12
#  Current loss 1.1585317850112915
#
# Epoch number 12
#  Current loss 1.2733500003814697
#
# Epoch number 12
#  Current loss 1.1677601337432861
#
# Epoch number 12
#  Current loss 1.4577363729476929
#
# Epoch number 12
#  Current loss 1.329758882522583
#
# Epoch number 12
#  Current loss 1.2451118230819702
#
# Epoch number 12
#  Current loss 1.4366931915283203
#
# Epoch number 12
#  Current loss 1.2984637022018433
#
# Epoch number 12
#  Current loss 1.204223871231079
#
# Epoch number 12
#  Current loss 1.3890594244003296
#
# Epoch number 12
#  Current loss 1.2773628234863281
#
# Epoch number 12
#  Current loss 1.9091367721557617
#
# Epoch number 12
#  Current loss 1.1909486055374146
#
# Epoch number 13
#  Current loss 1.1854618787765503
#
# Epoch number 13
#  Current loss 1.267059564590454
#
# Epoch number 13
#  Current loss 1.0719176530838013
#
# Epoch number 13
#  Current loss 1.1046433448791504
#
# Epoch number 13
#  Current loss 1.1929914951324463
#
# Epoch number 13
#  Current loss 1.790472149848938
#
# Epoch number 13
#  Current loss 1.2437695264816284
#
# Epoch number 13
#  Current loss 1.383539080619812
#
# Epoch number 13
#  Current loss 1.0725514888763428
#
# Epoch number 13
#  Current loss 1.2701410055160522
#
# Epoch number 13
#  Current loss 1.1874446868896484
#
# Epoch number 13
#  Current loss 1.2202293872833252
#
# Epoch number 13
#  Current loss 1.13688063621521
#
# Epoch number 13
#  Current loss 1.161763072013855
#
# Epoch number 13
#  Current loss 1.1406481266021729
#
# Epoch number 14
#  Current loss 0.9400455355644226
#
# Epoch number 14
#  Current loss 1.1735022068023682
#
# Epoch number 14
#  Current loss 1.237321138381958
#
# Epoch number 14
#  Current loss 1.2366790771484375
#
# Epoch number 14
#  Current loss 1.3087985515594482
#
# Epoch number 14
#  Current loss 1.049421787261963
#
# Epoch number 14
#  Current loss 0.6725735068321228
#
# Epoch number 14
#  Current loss 1.1273198127746582
#
# Epoch number 14
#  Current loss 1.039226770401001
#
# Epoch number 14
#  Current loss 2.9821972846984863
#
# Epoch number 14
#  Current loss 1.321364402770996
#
# Epoch number 14
#  Current loss 1.1177188158035278
#
# Epoch number 14
#  Current loss 1.599291205406189
#
# Epoch number 14
#  Current loss 1.1379497051239014
#
# Epoch number 14
#  Current loss 1.2037192583084106
#
# Epoch number 15
#  Current loss 1.1039958000183105
#
# Epoch number 15
#  Current loss 0.9964337944984436
#
# Epoch number 15
#  Current loss 1.216779112815857
#
# Epoch number 15
#  Current loss 1.1467746496200562
#
# Epoch number 15
#  Current loss 1.2716090679168701
#
# Epoch number 15
#  Current loss 1.2700767517089844
#
# Epoch number 15
#  Current loss 1.400174856185913
#
# Epoch number 15
#  Current loss 0.9370602965354919
#
# Epoch number 15
#  Current loss 1.62986159324646
#
# Epoch number 15
#  Current loss 1.010587215423584
#
# Epoch number 15
#  Current loss 1.2244093418121338
#
# Epoch number 15
#  Current loss 1.5161535739898682
#
# Epoch number 15
#  Current loss 1.1209242343902588
#
# Epoch number 15
#  Current loss 1.1668415069580078
#
# Epoch number 15
#  Current loss 1.4719668626785278
#
# Epoch number 16
#  Current loss 1.1326687335968018
#
# Epoch number 16
#  Current loss 1.4918756484985352
#
# Epoch number 16
#  Current loss 1.0933353900909424
#
# Epoch number 16
#  Current loss 1.0313961505889893
#
# Epoch number 16
#  Current loss 1.3932983875274658
#
# Epoch number 16
#  Current loss 1.2106727361679077
#
# Epoch number 16
#  Current loss 1.1629548072814941
#
# Epoch number 16
#  Current loss 1.3334378004074097
#
# Epoch number 16
#  Current loss 1.0987625122070312
#
# Epoch number 16
#  Current loss 1.1964232921600342
#
# Epoch number 16
#  Current loss 1.4244959354400635
#
# Epoch number 16
#  Current loss 1.1828480958938599
#
# Epoch number 16
#  Current loss 1.2697908878326416
#
# Epoch number 16
#  Current loss 1.163873314857483
#
# Epoch number 16
#  Current loss 1.1417427062988281
#
# Epoch number 17
#  Current loss 1.1265692710876465
#
# Epoch number 17
#  Current loss 1.1316701173782349
#
# Epoch number 17
#  Current loss 1.2484380006790161
#
# Epoch number 17
#  Current loss 1.1422526836395264
#
# Epoch number 17
#  Current loss 1.2614408731460571
#
# Epoch number 17
#  Current loss 1.1612236499786377
#
# Epoch number 17
#  Current loss 1.1020476818084717
#
# Epoch number 17
#  Current loss 1.2364110946655273
#
# Epoch number 17
#  Current loss 1.218226432800293
#
# Epoch number 17
#  Current loss 1.3084789514541626
#
# Epoch number 17
#  Current loss 1.1604866981506348
#
# Epoch number 17
#  Current loss 1.1903536319732666
#
# Epoch number 17
#  Current loss 1.2453497648239136
#
# Epoch number 17
#  Current loss 1.210716962814331
#
# Epoch number 17
#  Current loss 1.105546474456787
#
# Epoch number 18
#  Current loss 1.0124456882476807
#
# Epoch number 18
#  Current loss 1.1744451522827148
#
# Epoch number 18
#  Current loss 1.1854361295700073
#
# Epoch number 18
#  Current loss 1.0458012819290161
#
# Epoch number 18
#  Current loss 1.365509033203125
#
# Epoch number 18
#  Current loss 1.4560670852661133
#
# Epoch number 18
#  Current loss 1.1073347330093384
#
# Epoch number 18
#  Current loss 1.0919361114501953
#
# Epoch number 18
#  Current loss 1.291097640991211
#
# Epoch number 18
#  Current loss 0.9791983366012573
#
# Epoch number 18
#  Current loss 1.094151496887207
#
# Epoch number 18
#  Current loss 1.1786062717437744
#
# Epoch number 18
#  Current loss 1.1816307306289673
#
# Epoch number 18
#  Current loss 1.1745262145996094
#
# Epoch number 18
#  Current loss 1.068112850189209
#
# Epoch number 19
#  Current loss 1.1286896467208862
#
# Epoch number 19
#  Current loss 1.3123341798782349
#
# Epoch number 19
#  Current loss 1.1376060247421265
#
# Epoch number 19
#  Current loss 1.2093143463134766
#
# Epoch number 19
#  Current loss 0.7738778591156006
#
# Epoch number 19
#  Current loss 1.2716861963272095
#
# Epoch number 19
#  Current loss 1.1866495609283447
#
# Epoch number 19
#  Current loss 1.161769151687622
#
# Epoch number 19
#  Current loss 1.2456518411636353
#
# Epoch number 19
#  Current loss 0.9180057644844055
#
# Epoch number 19
#  Current loss 1.2865536212921143
#
# Epoch number 19
#  Current loss 1.4001078605651855
#
# Epoch number 19
#  Current loss 1.3889442682266235
#
# Epoch number 19
#  Current loss 1.0207786560058594
#
# Epoch number 19
#  Current loss 1.3097267150878906
#
# Model Saved Successfully

# %%
# Load the saved model
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = SiameseNetwork().to(device)
model.load_state_dict(torch.load("model.pt"))
# Out:
# IncompatibleKeys(missing_keys=[], unexpected_keys=[])

# %%
# Load the test dataset
test_dataset = SiameseNetworkDataset(training_csv=testing_csv,training_dir=testing_dir,
                                        transform=transforms.Compose([transforms.Resize((105,105)),
                                                                      transforms.ToTensor()
                                                                      ])
                                       )

test_dataloader = DataLoader(test_dataset,num_workers=6,batch_size=1,shuffle=True)

# %%
# Print the sample outputs to view its dissimilarity
counter=0
list_0 = torch.FloatTensor([[0]])
list_1 = torch.FloatTensor([[1]])
for i, data in enumerate(test_dataloader,0): 
  x0, x1 , label = data
  concatenated = torch.cat((x0,x1),0)
  output1,output2 = model(x0.to(device),x1.to(device))
  eucledian_distance = F.pairwise_distance(output1, output2)
  if label==list_0:
    label="Orginial"
  else:
    label="Forged"
  imshow(torchvision.utils.make_grid(concatenated),'Dissimilarity: {:.2f} Label: {}'.format(eucledian_distance.item(),label))
  counter=counter+1
  if counter ==20:
     break
